# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import requests
import json
import os
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ## IMPORTING DATASETS

# %%
sample_df = pd.read_csv('Sample.csv')
ground_truth_df = pd.read_csv('ground-truth.csv')

# %%
sample_df.head()
# Out:
#    creative_data_id                            creative_data_title  \
# 0           2194673                   30s Kim's Discount - 2194673
# 1           2142915                         30s New Flat - 2142915
# 2           1702851  30s Most Pills Don't Finish the Job - 1702851
# 3           1671980                         30s Box Vlog - 1671980
# 4           1749291          30s Scars: One Way Out [T1] - 1749291
#
#                            creative_data_description  creative_data_duration  \
# 0  Kim is going for the State Farm Drive Safe & S...                      30
# 1  Uncomfortable with her shabby apartment and ro...                      30
# 2  Flonase guesses you wouldn't accept an incompl...                      30
# 3  The Progressive Box starts his own vlog as he ...                      30
# 4  Chevrolet owners tell stories of how their Sil...                      30
#
#    creative_data_lifetime_spend_estimated  \
# 0                             29789808.73
# 1                              5423001.70
# 2                             23072716.78
# 3                             44909836.61
# 4                              3490623.10
#
#    creative_data_lifetime_airings_count creative_data_airing_date_first_et  \
# 0                                 13949          2019-04-06T22:19:06-04:00
# 1                                 10132          2019-03-04T06:49:02-05:00
# 2                                  8491          2018-02-19T07:42:14-05:00
# 3                                  7766          2018-01-01T00:17:22-05:00
# 4                                  5260          2018-05-01T07:07:56-04:00
#
#   creative_data_airing_date_last_et  \
# 0         2020-08-04T18:42:50-04:00
# 1         2021-08-03T11:12:36-04:00
# 2         2020-06-01T04:22:16-04:00
# 3         2018-06-10T15:53:15-04:00
# 4         2019-06-30T23:24:28-04:00
#
#                                               speech
# 0  So Kim, you going for a big drive safe and sav...
# 1  Check your credit scores for free and learn ho...
# 2  You wouldn't accept an incomplete job from any...
# 3  Subword. It's the box with 30% savings for saf...
# 4  I got scar tissue there. Same thing with any D...

# %% [markdown]
# ## Setting up the LLaVa model from TERMINAL
# LLaVA (Large Language-and-Vision Assistant) is an end-to-end trained large multimodal model that connects a vision encoder and LLM for general-purpose visual and language understanding.
#
# The LLaVA model exhibits remarkable interactive capabilities between images and videos

# %%
# !git clone https://github.com/PKU-YuanGroup/Video-LLaVA
# Out:
# Cloning into 'Video-LLaVA'...
# remote: Enumerating objects: 961, done.
# remote: Counting objects: 100% (474/474), done.
# remote: Compressing objects: 100% (196/196), done.
# remote: Total 961 (delta 384), reused 283 (delta 278), pack-reused 487
# Receiving objects: 100% (961/961), 115.33 MiB | 49.79 MiB/s, done.
# Resolving deltas: 100% (524/524), done.

# %%
# !cd Video-LLaVA

# %%
# !pip install -e .
# Out:
# Obtaining file:///Users/navisha/Desktop/Prep/DATA%20initiative/Assessment%202
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Collecting torch==2.0.1 (from videollava==1.0.0)
#   Obtaining dependency information for torch==2.0.1 from https://files.pythonhosted.org/packages/85/68/f901437d3e3ef6fe97adb1f372479626d994185b8fa06803f5bdf3bb90fd/torch-2.0.1-cp311-none-macosx_11_0_arm64.whl.metadata
#   Downloading torch-2.0.1-cp311-none-macosx_11_0_arm64.whl.metadata (23 kB)
# Collecting torchvision==0.15.2 (from videollava==1.0.0)
#   Obtaining dependency information for torchvision==0.15.2 from https://files.pythonhosted.org/packages/8a/6d/d713159642b36c42f5b6871330241070797ec89d3f8855eeb91c8baddddd/torchvision-0.15.2-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading torchvision-0.15.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting transformers==4.31.0 (from videollava==1.0.0)
#   Obtaining dependency information for transformers==4.31.0 from https://files.pythonhosted.org/packages/21/02/ae8e595f45b6c8edee07913892b3b41f5f5f273962ad98851dc6a564bbb9/transformers-4.31.0-py3-none-any.whl.metadata
#   Downloading transformers-4.31.0-py3-none-any.whl.metadata (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers<0.14,>=0.12.1 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from videollava==1.0.0) (0.13.2)
# Collecting sentencepiece==0.1.99 (from videollava==1.0.0)
#   Obtaining dependency information for sentencepiece==0.1.99 from https://files.pythonhosted.org/packages/9f/f9/bb5cd5e7d426f9cb33159063f1dd74b08e23d4e95dc6372d7f2a394e2ef8/sentencepiece-0.1.99-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading sentencepiece-0.1.99-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Collecting shortuuid (from videollava==1.0.0)
#   Obtaining dependency information for shortuuid from https://files.pythonhosted.org/packages/c0/44/21d6bf170bf40b41396480d8d49ad640bca3f2b02139cd52aa1e272830a5/shortuuid-1.0.13-py3-none-any.whl.metadata
#   Downloading shortuuid-1.0.13-py3-none-any.whl.metadata (5.8 kB)
# Collecting accelerate==0.21.0 (from videollava==1.0.0)
#   Obtaining dependency information for accelerate==0.21.0 from https://files.pythonhosted.org/packages/70/f9/c381bcdd0c3829d723aa14eec8e75c6c377b4ca61ec68b8093d9f35fc7a7/accelerate-0.21.0-py3-none-any.whl.metadata
#   Downloading accelerate-0.21.0-py3-none-any.whl.metadata (17 kB)
# Collecting peft==0.4.0 (from videollava==1.0.0)
#   Obtaining dependency information for peft==0.4.0 from https://files.pythonhosted.org/packages/88/a0/6e1c23293a922a9c9e9bd8d56a60cd78ecf531fdabe45ac975e142bfbe86/peft-0.4.0-py3-none-any.whl.metadata
#   Downloading peft-0.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting bitsandbytes==0.41.0 (from videollava==1.0.0)
#   Obtaining dependency information for bitsandbytes==0.41.0 from https://files.pythonhosted.org/packages/b9/33/1cea2d1c909dd3e2b595f7b73c4417f3786c385a4b269a5c40c7699bb14b/bitsandbytes-0.41.0-py3-none-any.whl.metadata
#   Downloading bitsandbytes-0.41.0-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: pydantic<2,>=1 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from videollava==1.0.0) (1.10.8)
# Collecting markdown2[all] (from videollava==1.0.0)
#   Obtaining dependency information for markdown2[all] from https://files.pythonhosted.org/packages/70/8d/ee7f29f0c65f39ea0bb39eaa24c3563e95f8f434ec8c593441854d6df115/markdown2-2.5.0-py2.py3-none-any.whl.metadata
#   Downloading markdown2-2.5.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: numpy in /Users/navisha/anaconda3/lib/python3.11/site-packages (from videollava==1.0.0) (1.24.3)
# Collecting scikit-learn==1.2.2 (from videollava==1.0.0)
#   Obtaining dependency information for scikit-learn==1.2.2 from https://files.pythonhosted.org/packages/2f/fd/9fcbe7fe94150e72d87120cbc462bde1971c3674e726b81f4a4c4fdfa8e1/scikit_learn-1.2.2-cp311-cp311-macosx_12_0_arm64.whl.metadata
#   Downloading scikit_learn-1.2.2-cp311-cp311-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: requests in /Users/navisha/anaconda3/lib/python3.11/site-packages (from videollava==1.0.0) (2.31.0)
# Collecting httpx==0.24.0 (from videollava==1.0.0)
#   Obtaining dependency information for httpx==0.24.0 from https://files.pythonhosted.org/packages/4e/c1/692013f1e6115a061a14f6c7d05947515a1eb7b85ef6e9bf0ffbf0e92738/httpx-0.24.0-py3-none-any.whl.metadata
#   Downloading httpx-0.24.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting uvicorn (from videollava==1.0.0)
#   Obtaining dependency information for uvicorn from https://files.pythonhosted.org/packages/63/84/2a26b4eac1cf0c6b5b176dd4346cc4912af5e1b0efc150b865e28636ac34/uvicorn-0.30.3-py3-none-any.whl.metadata
#   Downloading uvicorn-0.30.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting fastapi (from videollava==1.0.0)
#   Obtaining dependency information for fastapi from https://files.pythonhosted.org/packages/a4/d4/eb78f7c2648a3585095623f207d7e4b85a1be30347e01e0fdcd1d7d167a9/fastapi-0.111.1-py3-none-any.whl.metadata
#   Downloading fastapi-0.111.1-py3-none-any.whl.metadata (26 kB)
# Collecting einops==0.6.1 (from videollava==1.0.0)
#   Obtaining dependency information for einops==0.6.1 from https://files.pythonhosted.org/packages/68/24/b05452c986e8eff11f47e123a40798ae693f2fa1ed2f9546094997d2f6be/einops-0.6.1-py3-none-any.whl.metadata
#   Downloading einops-0.6.1-py3-none-any.whl.metadata (12 kB)
# Collecting einops-exts==0.0.4 (from videollava==1.0.0)
#   Obtaining dependency information for einops-exts==0.0.4 from https://files.pythonhosted.org/packages/78/01/8da8dd078b354a89602a875d310a0d725dad92b5b4d61069576e0a0e02e4/einops_exts-0.0.4-py3-none-any.whl.metadata
#   Downloading einops_exts-0.0.4-py3-none-any.whl.metadata (621 bytes)
# Collecting timm==0.6.13 (from videollava==1.0.0)
#   Obtaining dependency information for timm==0.6.13 from https://files.pythonhosted.org/packages/f6/c6/806d9b2fa95f418ad700dd206a935d5e8d7355505589dd13a70eb3a45048/timm-0.6.13-py3-none-any.whl.metadata
#   Downloading timm-0.6.13-py3-none-any.whl.metadata (38 kB)
# Collecting tensorboardX==2.6.2.2 (from videollava==1.0.0)
#   Obtaining dependency information for tensorboardX==2.6.2.2 from https://files.pythonhosted.org/packages/44/71/f3e7c9b2ab67e28c572ab4e9d5fa3499e0d252650f96d8a3a03e26677f53/tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting gradio==3.37.0 (from videollava==1.0.0)
#   Obtaining dependency information for gradio==3.37.0 from https://files.pythonhosted.org/packages/41/b6/eb030aa054e51be202c8aee0a6b5fefb35527499c914019f1f2741537029/gradio-3.37.0-py3-none-any.whl.metadata
#   Downloading gradio-3.37.0-py3-none-any.whl.metadata (17 kB)
# Collecting gradio-client==0.7.0 (from videollava==1.0.0)
#   Obtaining dependency information for gradio-client==0.7.0 from https://files.pythonhosted.org/packages/34/0d/94ef1fe636519984b50a1a8dc1339601e45af32b9cf7e78c67e595a75c73/gradio_client-0.7.0-py3-none-any.whl.metadata
#   Downloading gradio_client-0.7.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from accelerate==0.21.0->videollava==1.0.0) (23.2)
# Requirement already satisfied: psutil in /Users/navisha/anaconda3/lib/python3.11/site-packages (from accelerate==0.21.0->videollava==1.0.0) (5.9.0)
# Requirement already satisfied: pyyaml in /Users/navisha/anaconda3/lib/python3.11/site-packages (from accelerate==0.21.0->videollava==1.0.0) (6.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from gradio==3.37.0->videollava==1.0.0) (22.1.0)
# Requirement already satisfied: aiohttp~=3.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from gradio==3.37.0->videollava==1.0.0) (3.8.5)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from gradio==3.37.0->videollava==1.0.0) (5.2.0)
# Collecting ffmpy (from gradio==3.37.0->videollava==1.0.0)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: huggingface-hub>=0.14.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from gradio==3.37.0->videollava==1.0.0) (0.15.1)
# Requirement already satisfied: jinja2<4.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from gradio==3.37.0->videollava==1.0.0) (3.1.2)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from gradio==3.37.0->videollava==1.0.0) (2.2.0)
# Requirement already satisfied: markupsafe~=2.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from gradio==3.37.0->videollava==1.0.0) (2.1.1)
# Requirement already satisfied: matplotlib~=3.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from gradio==3.37.0->videollava==1.0.0) (3.7.2)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from gradio==3.37.0->videollava==1.0.0) (0.3.0)
# Collecting orjson~=3.0 (from gradio==3.37.0->videollava==1.0.0)
#   Obtaining dependency information for orjson~=3.0 from https://files.pythonhosted.org/packages/c2/88/9b7f032f11eef88e56559fb7d8fff70dbc43b95de4acd0b43acf1b235034/orjson-3.10.6-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata
#   Downloading orjson-3.10.6-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas<3.0,>=1.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from gradio==3.37.0->videollava==1.0.0) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from gradio==3.37.0->videollava==1.0.0) (9.4.0)
# Collecting pydub (from gradio==3.37.0->videollava==1.0.0)
#   Obtaining dependency information for pydub from https://files.pythonhosted.org/packages/a6/53/d78dc063216e62fc55f6b2eebb447f6a4b0a59f55c8406376f76bf959b08/pydub-0.25.1-py2.py3-none-any.whl.metadata
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart (from gradio==3.37.0->videollava==1.0.0)
#   Obtaining dependency information for python-multipart from https://files.pythonhosted.org/packages/3d/47/444768600d9e0ebc82f8e347775d24aef8f6348cf00e9fa0e81910814e6d/python_multipart-0.0.9-py3-none-any.whl.metadata
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Collecting semantic-version~=2.0 (from gradio==3.37.0->videollava==1.0.0)
#   Obtaining dependency information for semantic-version~=2.0 from https://files.pythonhosted.org/packages/6a/23/8146aad7d88f4fcb3a6218f41a60f6c2d4e3a72de72da1825dc7c8f7877c/semantic_version-2.10.0-py2.py3-none-any.whl.metadata
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: typing-extensions~=4.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from gradio==3.37.0->videollava==1.0.0) (4.12.2)
# Collecting websockets<12.0,>=10.0 (from gradio==3.37.0->videollava==1.0.0)
#   Obtaining dependency information for websockets<12.0,>=10.0 from https://files.pythonhosted.org/packages/8c/a8/e81533499f84ef6cdd95d11d5b05fa827c0f097925afd86f16e6a2631d8e/websockets-11.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading websockets-11.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: fsspec in /Users/navisha/anaconda3/lib/python3.11/site-packages (from gradio-client==0.7.0->videollava==1.0.0) (2023.4.0)
# Requirement already satisfied: certifi in /Users/navisha/anaconda3/lib/python3.11/site-packages (from httpx==0.24.0->videollava==1.0.0) (2023.7.22)
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx==0.24.0->videollava==1.0.0)
#   Obtaining dependency information for httpcore<0.18.0,>=0.15.0 from https://files.pythonhosted.org/packages/94/2c/2bde7ff8dd2064395555220cbf7cba79991172bf5315a07eb3ac7688d9f1/httpcore-0.17.3-py3-none-any.whl.metadata
#   Downloading httpcore-0.17.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: idna in /Users/navisha/anaconda3/lib/python3.11/site-packages (from httpx==0.24.0->videollava==1.0.0) (3.4)
# Requirement already satisfied: sniffio in /Users/navisha/anaconda3/lib/python3.11/site-packages (from httpx==0.24.0->videollava==1.0.0) (1.2.0)
# Requirement already satisfied: safetensors in /Users/navisha/anaconda3/lib/python3.11/site-packages (from peft==0.4.0->videollava==1.0.0) (0.3.2)
# Requirement already satisfied: scipy>=1.3.2 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from scikit-learn==1.2.2->videollava==1.0.0) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from scikit-learn==1.2.2->videollava==1.0.0) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from scikit-learn==1.2.2->videollava==1.0.0) (2.2.0)
# Requirement already satisfied: protobuf>=3.20 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from tensorboardX==2.6.2.2->videollava==1.0.0) (4.25.3)
# Requirement already satisfied: filelock in /Users/navisha/anaconda3/lib/python3.11/site-packages (from torch==2.0.1->videollava==1.0.0) (3.9.0)
# Requirement already satisfied: sympy in /Users/navisha/anaconda3/lib/python3.11/site-packages (from torch==2.0.1->videollava==1.0.0) (1.11.1)
# Requirement already satisfied: networkx in /Users/navisha/anaconda3/lib/python3.11/site-packages (from torch==2.0.1->videollava==1.0.0) (3.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from transformers==4.31.0->videollava==1.0.0) (2022.7.9)
# Requirement already satisfied: tqdm>=4.27 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from transformers==4.31.0->videollava==1.0.0) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from requests->videollava==1.0.0) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from requests->videollava==1.0.0) (1.26.16)
# Requirement already satisfied: click>=7.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from uvicorn->videollava==1.0.0) (8.0.4)
# Requirement already satisfied: h11>=0.8 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from uvicorn->videollava==1.0.0) (0.14.0)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->videollava==1.0.0)
#   Obtaining dependency information for starlette<0.38.0,>=0.37.2 from https://files.pythonhosted.org/packages/fd/18/31fa32ed6c68ba66220204ef0be798c349d0a20c1901f9d4a794e08c76d8/starlette-0.37.2-py3-none-any.whl.metadata
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting fastapi-cli>=0.0.2 (from fastapi->videollava==1.0.0)
#   Obtaining dependency information for fastapi-cli>=0.0.2 from https://files.pythonhosted.org/packages/a1/03/89bf615052aa5453c04d952225ded0b88aab6487b9c5f0c268939d13b860/fastapi_cli-0.0.4-py3-none-any.whl.metadata
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl.metadata (7.0 kB)
# Collecting email_validator>=2.0.0 (from fastapi->videollava==1.0.0)
#   Obtaining dependency information for email_validator>=2.0.0 from https://files.pythonhosted.org/packages/d7/ee/bf0adb559ad3c786f12bcbc9296b3f5675f529199bef03e2df281fa1fadb/email_validator-2.2.0-py3-none-any.whl.metadata
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: pygments>=2.7.3 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from markdown2[all]->videollava==1.0.0) (2.15.1)
# Collecting wavedrom (from markdown2[all]->videollava==1.0.0)
#   Downloading wavedrom-2.0.3.post3.tar.gz (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.7/137.7 kB 2.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting latex2mathml (from markdown2[all]->videollava==1.0.0)
#   Obtaining dependency information for latex2mathml from https://files.pythonhosted.org/packages/f2/0a/181ed55562ce90179aedf33b09fcd79db31c868a5d480f3cb71a31d19692/latex2mathml-3.77.0-py3-none-any.whl.metadata
#   Downloading latex2mathml-3.77.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from aiohttp~=3.0->gradio==3.37.0->videollava==1.0.0) (22.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from aiohttp~=3.0->gradio==3.37.0->videollava==1.0.0) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from aiohttp~=3.0->gradio==3.37.0->videollava==1.0.0) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from aiohttp~=3.0->gradio==3.37.0->videollava==1.0.0) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from aiohttp~=3.0->gradio==3.37.0->videollava==1.0.0) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from aiohttp~=3.0->gradio==3.37.0->videollava==1.0.0) (1.2.0)
# Requirement already satisfied: jsonschema>=3.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from altair<6.0,>=4.2.0->gradio==3.37.0->videollava==1.0.0) (4.17.3)
# Requirement already satisfied: toolz in /Users/navisha/anaconda3/lib/python3.11/site-packages (from altair<6.0,>=4.2.0->gradio==3.37.0->videollava==1.0.0) (0.12.0)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi->videollava==1.0.0)
#   Obtaining dependency information for dnspython>=2.0.0 from https://files.pythonhosted.org/packages/87/a1/8c5287991ddb8d3e4662f71356d9656d91ab3a36618c3dd11b280df0d255/dnspython-2.6.1-py3-none-any.whl.metadata
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: typer>=0.12.3 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from fastapi-cli>=0.0.2->fastapi->videollava==1.0.0) (0.12.3)
# Requirement already satisfied: anyio<5.0,>=3.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from httpcore<0.18.0,>=0.15.0->httpx==0.24.0->videollava==1.0.0) (3.5.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.37.0->videollava==1.0.0) (0.1.0)
# Requirement already satisfied: linkify-it-py<3,>=1 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.37.0->videollava==1.0.0) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==3.37.0->videollava==1.0.0) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==3.37.0->videollava==1.0.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==3.37.0->videollava==1.0.0) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==3.37.0->videollava==1.0.0) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==3.37.0->videollava==1.0.0) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from matplotlib~=3.0->gradio==3.37.0->videollava==1.0.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio==3.37.0->videollava==1.0.0) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from pandas<3.0,>=1.0->gradio==3.37.0->videollava==1.0.0) (2023.3)
# Collecting httptools>=0.5.0 (from uvicorn->videollava==1.0.0)
#   Obtaining dependency information for httptools>=0.5.0 from https://files.pythonhosted.org/packages/f5/d1/53283b96ed823d5e4d89ee9aa0f29df5a1bdf67f148e061549a595d534e4/httptools-0.6.1-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading httptools-0.6.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from uvicorn->videollava==1.0.0) (0.21.0)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn->videollava==1.0.0)
#   Obtaining dependency information for uvloop!=0.15.0,!=0.15.1,>=0.14.0 from https://files.pythonhosted.org/packages/41/2a/608ad69f27f51280098abee440c33e921d3ad203e2c86f7262e241e49c99/uvloop-0.19.0-cp311-cp311-macosx_10_9_universal2.whl.metadata
#   Downloading uvloop-0.19.0-cp311-cp311-macosx_10_9_universal2.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn->videollava==1.0.0)
#   Obtaining dependency information for watchfiles>=0.13 from https://files.pythonhosted.org/packages/0a/6d/27326918be98fee2694916b90e4c447745fd2935d9b410a768a746c2bafc/watchfiles-0.22.0-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading watchfiles-0.22.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: mpmath>=0.19 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from sympy->torch==2.0.1->videollava==1.0.0) (1.3.0)
# Collecting svgwrite (from wavedrom->markdown2[all]->videollava==1.0.0)
#   Obtaining dependency information for svgwrite from https://files.pythonhosted.org/packages/84/15/640e399579024a6875918839454025bb1d5f850bb70d96a11eabb644d11c/svgwrite-1.4.3-py3-none-any.whl.metadata
#   Downloading svgwrite-1.4.3-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: six in /Users/navisha/anaconda3/lib/python3.11/site-packages (from wavedrom->markdown2[all]->videollava==1.0.0) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==3.37.0->videollava==1.0.0) (0.18.0)
# Requirement already satisfied: uc-micro-py in /Users/navisha/anaconda3/lib/python3.11/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio==3.37.0->videollava==1.0.0) (1.0.1)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->videollava==1.0.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /Users/navisha/anaconda3/lib/python3.11/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->videollava==1.0.0) (13.7.1)
# Downloading accelerate-0.21.0-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 9.3 MB/s eta 0:00:00
# Downloading bitsandbytes-0.41.0-py3-none-any.whl (92.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 31.0 MB/s eta 0:00:0000:0100:01
# Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 874.0 kB/s eta 0:00:00
# Downloading einops_exts-0.0.4-py3-none-any.whl (3.9 kB)
# Downloading gradio-3.37.0-py3-none-any.whl (19.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 58.6 MB/s eta 0:00:0000:0100:01
# Downloading gradio_client-0.7.0-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.7/302.7 kB 32.8 MB/s eta 0:00:00
# Downloading httpx-0.24.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 12.6 MB/s eta 0:00:00
# Downloading peft-0.4.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 15.3 MB/s eta 0:00:00
# Downloading scikit_learn-1.2.2-cp311-cp311-macosx_12_0_arm64.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 44.8 MB/s eta 0:00:00a 0:00:01
# Downloading sentencepiece-0.1.99-cp311-cp311-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.0 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 17.0 MB/s eta 0:00:00
# Downloading timm-0.6.13-py3-none-any.whl (549 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 549.1/549.1 kB 41.4 MB/s eta 0:00:00
# Downloading torch-2.0.1-cp311-none-macosx_11_0_arm64.whl (55.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 MB 22.2 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.15.2-cp311-cp311-macosx_11_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 29.0 MB/s eta 0:00:0000:01
# Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 58.2 MB/s eta 0:00:0000:0100:01
# Downloading uvicorn-0.30.3-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 9.4 MB/s eta 0:00:00
# Downloading fastapi-0.111.1-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/92.2 kB 13.6 MB/s eta 0:00:00
# Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Downloading httpcore-0.17.3-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 13.9 MB/s eta 0:00:00
# Downloading orjson-3.10.6-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.5/250.5 kB 28.2 MB/s eta 0:00:00
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 8.3 MB/s eta 0:00:00
# Downloading websockets-11.0.3-cp311-cp311-macosx_11_0_arm64.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.0/121.0 kB 14.8 MB/s eta 0:00:00
# Downloading latex2mathml-3.77.0-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 8.4 MB/s eta 0:00:00
# Downloading markdown2-2.5.0-py2.py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 5.1 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 31.8 MB/s eta 0:00:00
# Downloading httptools-0.6.1-cp311-cp311-macosx_10_9_universal2.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.9/145.9 kB 18.2 MB/s eta 0:00:00
# Downloading uvloop-0.19.0-cp311-cp311-macosx_10_9_universal2.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 47.9 MB/s eta 0:00:00
# Downloading watchfiles-0.22.0-cp311-cp311-macosx_11_0_arm64.whl (391 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 391.2/391.2 kB 36.1 MB/s eta 0:00:00
# Downloading svgwrite-1.4.3-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 9.2 MB/s eta 0:00:00
# Building wheels for collected packages: videollava, ffmpy, wavedrom
#   Building editable for videollava (pyproject.toml) ... done
#   Created wheel for videollava: filename=videollava-1.0.0-0.editable-py3-none-any.whl size=14041 sha256=8d967b2abd5bbc0d47e3c3e366f6c9d4b93ac2af00a6ab1606094c79697a72a1
#   Stored in directory: /private/var/folders/f1/cw0kp_854qjb3mj_4q3wrw0w0000gn/T/pip-ephem-wheel-cache-_1degj1b/wheels/c7/b6/a1/8f607e19132d0c95ebe7b86da6a86da25997c490d2cd8262fc
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5583 sha256=dff53d452a171f03bdcdbad56c3dcd593a4d881f67beab555a5b99042e9cf108
#   Stored in directory: /Users/navisha/Library/Caches/pip/wheels/55/3c/f2/f6e34046bac0d57c13c7d08123b85872423b89c8f59bafda51
#   Building wheel for wavedrom (setup.py) ... done
#   Created wheel for wavedrom: filename=wavedrom-2.0.3.post3-py2.py3-none-any.whl size=30051 sha256=51f2a4cd92abeb8f022aeb71680cc3e4dbc29452846fad45a2036d3986f85491
#   Stored in directory: /Users/navisha/Library/Caches/pip/wheels/23/cf/3b/4dcf6b22fa41c5ece715fa5f4e05afd683e7b0ce0f2fcc7bb6
# Successfully built videollava ffmpy wavedrom
# Installing collected packages: sentencepiece, pydub, ffmpy, bitsandbytes, websockets, uvloop, uvicorn, tensorboardX, svgwrite, shortuuid, semantic-version, python-multipart, orjson, markdown2, latex2mathml, httptools, einops, dnspython, wavedrom, watchfiles, torch, starlette, scikit-learn, httpcore, email_validator, einops-exts, transformers, torchvision, httpx, accelerate, timm, peft, gradio-client, fastapi-cli, fastapi, gradio, videollava
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.1
#     Uninstalling torch-2.3.1:
#       Successfully uninstalled torch-2.3.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.0
#     Uninstalling scikit-learn-1.3.0:
#       Successfully uninstalled scikit-learn-1.3.0
#   Attempting uninstall: httpcore
#     Found existing installation: httpcore 1.0.4
#     Uninstalling httpcore-1.0.4:
#       Successfully uninstalled httpcore-1.0.4
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.32.1
#     Uninstalling transformers-4.32.1:
#       Successfully uninstalled transformers-4.32.1
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.18.1
#     Uninstalling torchvision-0.18.1:
#       Successfully uninstalled torchvision-0.18.1
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.27.0
#     Uninstalling httpx-0.27.0:
#       Successfully uninstalled httpx-0.27.0
# Successfully installed accelerate-0.21.0 bitsandbytes-0.41.0 dnspython-2.6.1 einops-0.6.1 einops-exts-0.0.4 email_validator-2.2.0 fastapi-0.111.1 fastapi-cli-0.0.4 ffmpy-0.3.2 gradio-3.37.0 gradio-client-0.7.0 httpcore-0.17.3 httptools-0.6.1 httpx-0.24.0 latex2mathml-3.77.0 markdown2-2.5.0 orjson-3.10.6 peft-0.4.0 pydub-0.25.1 python-multipart-0.0.9 scikit-learn-1.2.2 semantic-version-2.10.0 sentencepiece-0.1.99 shortuuid-1.0.13 starlette-0.37.2 svgwrite-1.4.3 tensorboardX-2.6.2.2 timm-0.6.13 torch-2.0.1 torchvision-0.15.2 transformers-4.31.0 uvicorn-0.30.3 uvloop-0.19.0 videollava-1.0.0 watchfiles-0.22.0 wavedrom-2.0.3.post3 websockets-11.0.3

# %%
# !pip install flash-attn --no-build-isolation
# Out:
# Collecting flash-attn
#   Downloading flash_attn-2.6.2.tar.gz (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 26.6 MB/s eta 0:00:0000:010:01m
#   Preparing metadata (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [22 lines of output]
#       fatal: not a git repository (or any of the parent directories): .git
#       /private/var/folders/f1/cw0kp_854qjb3mj_4q3wrw0w0000gn/T/pip-install-90nibdwb/flash-attn_e2a997ddc547437487969db708ca8d16/setup.py:95: UserWarning: flash_attn was requested, but nvcc was not found.  Are you sure your environment has nvcc available?  If you're installing within a container from https://hub.docker.com/r/pytorch/pytorch, only images whose names contain 'devel' will provide nvcc.
#         warnings.warn(
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/private/var/folders/f1/cw0kp_854qjb3mj_4q3wrw0w0000gn/T/pip-install-90nibdwb/flash-attn_e2a997ddc547437487969db708ca8d16/setup.py", line 179, in <module>
#           CUDAExtension(
#         File "/Users/navisha/anaconda3/lib/python3.11/site-packages/torch/utils/cpp_extension.py", line 1048, in CUDAExtension
#           library_dirs += library_paths(cuda=True)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/navisha/anaconda3/lib/python3.11/site-packages/torch/utils/cpp_extension.py", line 1179, in library_paths
#           if (not os.path.exists(_join_cuda_home(lib_dir)) and
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/navisha/anaconda3/lib/python3.11/site-packages/torch/utils/cpp_extension.py", line 2223, in _join_cuda_home
#           raise EnvironmentError('CUDA_HOME environment variable is not set. '
#       OSError: CUDA_HOME environment variable is not set. Please set it to your CUDA install root.
#
#
#       torch.__version__  = 2.0.1
#
#
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
ground_truth_df.head()
# Out:
#             Timestamp  creative_data_id  \
# 0   5/16/2024 8:00:14           1471363
# 1   5/23/2024 2:35:55           1471363
# 2  5/15/2024 18:09:54           1488315
# 3   5/16/2024 6:18:34           1488315
# 4  5/24/2024 10:00:26           1488315
#
#   Is there a call to go online (e.g., shop online, visit the Web)?   \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Is there online contact information provided (e.g., URL, website)?   \
# 0                                                Yes
# 1                                                Yes
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Is there a visual or verbal call to purchase (e.g., buy now, order now)?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Does the ad portray a sense of urgency to act (e.g., buy before sales ends, order before ends)?   \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Is there an incentive to buy (e.g., a discount, a coupon, a sale or "limited time offer")?   \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Is there offline contact information provided (e.g., phone, mail, store location)?  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Is there mention of something free?   \
# 0                                   No
# 1                                   No
# 2                                   No
# 3                                   No
# 4                                   No
#
#   Does the ad mention at least one specific product or service (e.g., model, type, item)?   \
# 0                                                Yes
# 1                                                Yes
# 2                                                 No
# 3                                                Yes
# 4                                                Yes
#
#    ... Was there a famous person in this ad?   \
# 0  ...                                     No
# 1  ...                                     No
# 2  ...                                     No
# 3  ...                                     No
# 4  ...                                     No
#
#   If yes to the above, write the name of the famous person, if known.  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   What happened in this ad? (Answer in 2-3 sentences each)  \
# 0  During this ad we had a man and a woman taking...
# 1  We watch Mini USA new Countryman driver around...
# 2  The end of the world seems to have been brough...
# 3  This ad is set in a bar in the middle of a des...
# 4  It started with a disaster occurring and the n...
#
#   What was/were the company's goal(s) with this ad? Choose (potentially multiple) from:  \
# 0  Change how consumers feel about the product/br...
# 1            Directly persuade consumers to purchase
# 2  Increase awareness of product/brand, Make cons...
# 3  Increase awareness of product/brand, Change ho...
# 4                Increase awareness of product/brand
#
#   How successful was the ad in achieving its goal(s)?  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  4
# 4                                                  4
#
#   How much did you like the ad? (1. Strongly dislike, 2. Dislike, 3. Neither Like or Dislike, 4. Like, 5. Strongly Like)  \
# 0                                                  3
# 1                                                  2
# 2                                                  3
# 3                                                  4
# 4                                                  3
#
#     What was the slogan presented in the ad, if any?  \
# 0                                                NaN
# 1                                                n/a
# 2  Their usual slogan was not presented, but "Tom...
# 3                    Cuervo, "Tomorrow is Overrated"
# 4                              Tomorrow is overrated
#
#   After addressing the specific survey items, write a general description of the ad. You can use answers to the questions above to formulate your answer. Your description should include:\nBrand and Product Identification: \nSpecify the brand and whether a product is being advertised. (1 sentence)\nVisual Elements: Describe what is seen on the screen, including setting, characters, and any text or graphics. (max 2 sentences)\nAuditory Elements: Note what is heard, such as dialogue, voice-over, music, or sound effects. (max 2 sentences)\n  \
# 0  Product Identification: Mini Countryman SUV\nM...
# 1  Mini USA is advertising their new Countryman c...
# 2  The brand being advertised is Jose Cuervo tequ...
# 3  This ad is for the brand Jose Cuervo, advertis...
# 4  The brand being advertised was Jose Cuervo teq...
#
#   Any additional feedback or things we should be aware of?   \
# 0  I believe the text legibility should be improv...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Please enter the video identifier one more time (e.g. 123456789.mp4)
# 0                                        1471363.mp4
# 1                                        1471363.mp4
# 2                                        1488315.mp4
# 3                                        1488315.mp4
# 4                                        1488315.mp4
#
# [5 rows x 36 columns]

# %%
#Prompt Engineering is important for the response from the LLM
prompt = """You are an assistant tasked to watch videos. You will be given description, speech, transcription etc for each video.
                              You will be asked a question related to the video. You only have to answer as Yes or No
                              Here is the description: As a man speeds down a country road in his Audi Q7, its pre-sense safety technology responds to a deer leaping suddenly in front of his car. Without missing a beat, the vehicle skids to a stop before the hair on the startled man's arms has time to rise. The Audi pre-sense is now available in the Audi A4.

                              Here is the speech:  Audi presens can help prepare for and in some cases help prevent collisions faster than well, you progress is amplifying your instincts. Audi Precent found in the Audi A four, get an exceptional offer at your local Audi dealer.
                              You will be asked the following three questions
                              1. Is there a call to go online?
                              Guidelines to answer this question: Say yes only if a website is shown at the end of the video or it is present in description or speech. Else say no
                              2. Is there mention of something free?
                              Guidelines to answer this question: Say yes only if the word free is explicitly mentioned in speech or description or if you see the word free in the video. Else say no.
                              3. Does the ad have cute elements?
                              Guidelines to answer this question: Say yes only if something is animated or small animals or babies. Else say no.

                              Here is your question: Is there mention of something free?"""

# %%
url = "http://127.0.0.1:5000/generate"
headers = {
    "Content-Type": "application/json"
}
data = {
    "file_paths": ["sample/1667694.mp4"],
    #"text": "Is there an incentive to buy?"
    "text": prompt
}

response = requests.post(url, headers=headers, data=json.dumps(data))

print(response.text)

# %%
# Code for creating a prompt and answering all questions from the questionnaire for each video

# %%
video_folder_path = 'sample/'

# %%
# Iterate over each file in the directory
for filename in os.listdir(video_folder_path):
    if filename.endswith(".mp4"):
        video_id = filename.split('.')[0]  # Assuming the filename is the creative_data_id

        video_data = sample_df[sample_df['creative_data_id'].astype(str) == video_id]

        if not video_data.empty:
            description = video_data['creative_data_description'].iloc[0]
            speech = video_data['speech'].iloc[0]
            prompt = f"""You are an assistant tasked to watch videos. You will be given description, speech, transcription etc for each video.
            You will be asked a question related to the video. You only have to answer as Yes or No

            Here is the description: {description}
            \n
            Here is the speech:  {speech}"""

            print("Processing video:", filename)
            print("Prompt:", prompt)
            print("\n")
        else:
            print("No data found for video ID:", video_id)

# Handle the case if no videos are found
if not any(filename.endswith(".mp4") for filename in os.listdir(video_folder_path)):
    print("No video files found in the directory.")
# Out:
# Processing video: 1526213.mp4
# Prompt: You are an assistant tasked to watch videos. You will be given description, speech, transcription etc for each video.
# You will be asked a question related to the video. You only have to answer as Yes or No
#
# Here is the description: As a man speeds down a country road in his Audi Q7, its pre-sense safety technology responds to a deer leaping suddenly in front of his car. Without missing a beat, the vehicle skids to a stop before the hair on the startled man's arms has time to rise. The Audi pre-sense is now available in the Audi A4.
#
#
# Here is the speech:  Audi presens can help prepare for and in some cases help prevent collisions faster than well, you progress is amplifying your instincts. Audi Precent found in the Audi A four, get an exceptional offer at your local Audi dealer.
#
#
# Processing video: 1471363.mp4
# Prompt: You are an assistant tasked to watch videos. You will be given description, speech, transcription etc for each video.
# You will be asked a question related to the video. You only have to answer as Yes or No
#
# Here is the description: The new MINI Countryman is the largest yet, providing space for additions. These additions come in the form of connectivity, all-wheel drive and space for gear, leaving just enough room for a few more additions: friends and stories.
#
#
# Here is the speech:  It's another pure gray morning. Don't know what the day is holding and I get up and walk right into the path of a, ok. The lightning.
#
#
# Processing video: 1488315.mp4
# Prompt: You are an assistant tasked to watch videos. You will be given description, speech, transcription etc for each video.
# You will be asked a question related to the video. You only have to answer as Yes or No
#
# Here is the description: What would you do if the end of the world was nigh? As the sky turns orange and meteors fall to the ground, a man walks up to the jukebox in a bar. He selects "It's Now or Never" by Elvis Presley and then turns around to dance with a woman. They dance like the world is not ending because, according to Jose Cuervo, "Tomorrow is Overrated."
#
#
# Here is the speech:  The end of civilization is upon us. Hold your loved ones close. Right. Because, well, you know. Yes.

# %%
# List of questions for the questionnaire (adding guidelines to make the response more accurate)
questions = [
    "Is there a call to go online? Guidelines: Say yes only if a website is shown at the end of the video or it is mentioned in the description or speech. Else say no.",
    "Is online contact information provided? Guidelines: Say yes only if any form of online contact information like an email, website URL, or social media link is shown or mentioned. Else say no.",
    "Is there a visual or verbal call to purchase? Guidelines: Say yes if the ad directly encourages viewers to buy a product or service, such as through phrases like 'buy now' or 'order today'. Else say no.",
    "Does the ad portray a sense of urgency to act? Guidelines: Say yes if there's a prompt suggesting limited time, like 'offer ends soon' or 'hurry, while supplies last'. Else say no.",
    "Is there an incentive to buy? Guidelines: Say yes if the ad offers discounts, coupons, sales, or exclusive deals. Else say no.",
    "Is offline contact information provided? Guidelines: Say yes if there's mention of physical contact details like a phone number or store location. Else say no.",
    "Is there mention of something free? Guidelines: Say yes only if the word 'free' is explicitly mentioned in the speech or description, or if you see the word free in the video. Else say no.",
    "Does the ad mention at least one specific product or service? Guidelines: Say yes if specific products or services are detailed. Else say no.",
    "Is there any verbal or visual mention of the price? Guidelines: Say yes if the price of a product or service is disclosed or shown. Else say no.",
    "Does the ad show the brand multiple times? Guidelines: Say yes if the brand's logo or name appears several times throughout the ad. Else say no.",
    "Does the ad show the brand exactly once at the end of the ad? Guidelines: Say yes if the brand's logo or name is shown only once, and it is at the end. Else say no.",
    "Is the ad intended to affect the viewer emotionally? Guidelines: Say yes if the ad aims to elicit emotions, whether positive or negative. Else say no.",
    "Does the ad give you a positive feeling about the brand? Guidelines: Say yes if the ad overall leaves a positive impression of the brand, regardless of personal opinion. Else say no.",
    "Does the ad have a story arc? Guidelines: Say yes if the ad has a clear beginning, middle, and end that tells a story. Else say no.",
    "Does the ad have a reversal of fortune? Guidelines: Say yes if the ad shows a significant change in circumstances, for better or worse. Else say no.",
    "Does the ad have relatable characters? Guidelines: Say yes if the characters in the ad are relatable or evoke empathy. Else say no.",
    "Is the ad creative/cleve? Guidelines: Say yes if the ad demonstrates originality or cleverness. Else say no.",
    "Is the ad intended to be funny? Guidelines: Say yes if the ad aims to be humorous, regardless of personal opinion on the humor. Else say no.",
    "Does this ad provide sensory stimulation? Guidelines: Say yes if the ad includes appealing visuals, enticing sounds, or other sensory details that capture attention. Else say no.",
    "Is the ad visually pleasing? Guidelines: Say yes if the ad is aesthetically attractive or has high-quality graphics and imagery. Else say no.",
    "Does the ad have cute elements? Guidelines: Say yes only if the ad contains animated features, small animals, or babies. Else say no."
]

# %%
results_df = pd.DataFrame(columns=['creative_data_id'] + [f'question_{i+1}' for i in range(len(questions))])

# %%
#wrote a script with flask to serve api and make it easier
# API details
url = "http://127.0.0.1:5000/generate"
headers = {"Content-Type": "application/json"}

# Iterating over each file in the directory
for filename in os.listdir(video_folder_path):
    if filename.endswith(".mp4"):
        video_id = filename.split('.')[0]  # Assuming the filename is the creative_data_id

        video_data = sample_df[sample_df['creative_data_id'].astype(str) == video_id]

        if not video_data.empty:
            description = video_data['creative_data_description'].iloc[0]
            speech = video_data['speech'].iloc[0]
            results = [video_id]

            for question in questions:
                prompt = f"""You are an assistant tasked to watch videos. You will be given description and speech for each video.
                              You will be asked a question related to the video. You only have to answer as Yes or No
                              Here is the description: {description}
                              Here is the speech:  {speech}
                              Here is your question: {question}"""

                data = json.dumps({"file_paths": [f"sample/{video_id}.mp4"], "text": prompt})
                response = requests.post(url, headers=headers, data=data)
                answer = json.loads(response.text)['response'].split("</s>")[0]
                results.append('yes' if answer.lower() == 'yes' else 'no')

            # Append the results for this video to the DataFrame
            print("Processing video:", filename)
            print(results)
            results_df.loc[len(results_df)] = results

# Save the DataFrame to a CSV file
results_df.to_csv('results.csv', index=False)
print("Completed processing all videos.")
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3170124.mp4
# ['3170124', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1958838.mp4
# ['1958838', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1683011.mp4
# ['1683011', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2454123.mp4
# ['2454123', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3059869.mp4
# ['3059869', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1825984.mp4
# ['1825984', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2418354.mp4
# ['2418354', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2381477.mp4
# ['2381477', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1942695.mp4
# ['1942695', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2032457.mp4
# ['2032457', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1676138.mp4
# ['1676138', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2488408.mp4
# ['2488408', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2332208.mp4
# ['2332208', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1739116.mp4
# ['1739116', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2513974.mp4
# ['2513974', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2506189.mp4
# ['2506189', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3265336.mp4
# ['3265336', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2917037.mp4
# ['2917037', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1713794.mp4
# ['1713794', 'no', 'no', 'no', 'yes', 'no', 'yes', 'yes', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3066063.mp4
# ['3066063', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3340369.mp4
# ['3340369', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1667694.mp4
# ['1667694', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1733728.mp4
# ['1733728', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2595709.mp4
# ['2595709', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2009582.mp4
# ['2009582', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2293300.mp4
# ['2293300', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1913310.mp4
# ['1913310', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2090919.mp4
# ['2090919', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2188255.mp4
# ['2188255', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3347554.mp4
# ['3347554', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3037506.mp4
# ['3037506', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3309933.mp4
# ['3309933', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2002557.mp4
# ['2002557', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2391348.mp4
# ['2391348', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1788954.mp4
# ['1788954', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2710205.mp4
# ['2710205', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1661301.mp4
# ['1661301', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1934234.mp4
# ['1934234', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2597996.mp4
# ['2597996', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2327954.mp4
# ['2327954', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1488315.mp4
# ['1488315', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2337786.mp4
# ['2337786', 'no', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2548638.mp4
# ['2548638', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2652509.mp4
# ['2652509', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2507887.mp4
# ['2507887', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2352149.mp4
# ['2352149', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2821872.mp4
# ['2821872', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3415261.mp4
# ['3415261', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3340033.mp4
# ['3340033', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2505712.mp4
# ['2505712', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2379465.mp4
# ['2379465', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3081313.mp4
# ['3081313', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1702851.mp4
# ['1702851', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2620437.mp4
# ['2620437', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2789795.mp4
# ['2789795', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3209706.mp4
# ['3209706', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2953810.mp4
# ['2953810', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2220795.mp4
# ['2220795', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1747914.mp4
# ['1747914', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2150923.mp4
# ['2150923', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3004458.mp4
# ['3004458', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2716616.mp4
# ['2716616', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2205093.mp4
# ['2205093', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2270982.mp4
# ['2270982', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2853933.mp4
# ['2853933', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2592911.mp4
# ['2592911', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1986629.mp4
# ['1986629', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2714373.mp4
# ['2714373', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1708967.mp4
# ['1708967', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3156128.mp4
# ['3156128', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2755227.mp4
# ['2755227', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1548815.mp4
# ['1548815', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1707220.mp4
# ['1707220', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3119347.mp4
# ['3119347', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3339840.mp4
# ['3339840', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2962688.mp4
# ['2962688', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3212463.mp4
# ['3212463', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3117116.mp4
# ['3117116', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3078623.mp4
# ['3078623', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1723501.mp4
# ['1723501', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2160345.mp4
# ['2160345', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3361032.mp4
# ['3361032', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1678735.mp4
# ['1678735', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3019128.mp4
# ['3019128', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1963503.mp4
# ['1963503', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2530396.mp4
# ['2530396', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'no']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3328522.mp4
# ['3328522', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2218186.mp4
# ['2218186', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1749291.mp4
# ['1749291', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2314704.mp4
# ['2314704', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2149098.mp4
# ['2149098', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3124938.mp4
# ['3124938', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3168530.mp4
# ['3168530', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2076630.mp4
# ['2076630', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1671980.mp4
# ['1671980', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1768584.mp4
# ['1768584', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1951792.mp4
# ['1951792', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3414303.mp4
# ['3414303', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3149347.mp4
# ['3149347', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1710855.mp4
# ['1710855', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2544459.mp4
# ['2544459', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3326009.mp4
# ['3326009', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2807978.mp4
# ['2807978', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2505718.mp4
# ['2505718', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1624211.mp4
# ['1624211', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1959692.mp4
# ['1959692', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2511206.mp4
# ['2511206', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3422482.mp4
# ['3422482', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2612386.mp4
# ['2612386', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 1625396.mp4
# ['1625396', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2238004.mp4
# ['2238004', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2764983.mp4
# ['2764983', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 3351059.mp4
# ['3351059', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Processing video: 2650588.mp4
# ['2650588', 'no', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes']
# Completed processing all videos.

# %%
#results_df

# %% [markdown]
# ## EVALUATION
#
# ground_truth_df needs to be analyzed and pre processed to calculate final majority vote and to make it more easy to compare with the results_df

# %%
#ground_truth_df.groupby('creative_data_id').first()

# %%
#ground_truth_df.isnull().sum()

# %%
#ground_truth_df.columns

# %%
#Dropping null value columns and columns that are not useful for comparing with the result dataframe
#ground_truth_df.drop(['Timestamp','Any additional feedback or things we should be aware of? ','Please enter the video identifier one more time (e.g. 123456789.mp4)', 'If "yes" to the above, which of the following emotions is closest to the emotion that the ad was intending the viewer to feel? (Select all that apply.)', 'If yes to the above, did the ad successfully affect you emotionally, as intended?', 'If yes to the above, was the ad successfully funny, as intended?' , 'If yes to the above, write the name of the famous person, if known.', 'What was the slogan presented in the ad, if any?', 'Was there a famous person in this ad? ',
      #  'What happened in this ad? (Answer in 2-3 sentences each)',
      #  "What was/were the company's goal(s) with this ad? Choose (potentially multiple) from:",
      #  'How successful was the ad in achieving its goal(s)?',
      #  'How much did you like the ad? (1. Strongly dislike, 2. Dislike, 3. Neither Like or Dislike, 4. Like, 5. Strongly Like)',
      #  'After addressing the specific survey items, write a general description of the ad. You can use answers to the questions above to formulate your answer. Your description should include:\nBrand and Product Identification: \nSpecify the brand and whether a product is being advertised. (1 sentence)\nVisual Elements: Describe what is seen on the screen, including setting, characters, and any text or graphics. (max 2 sentences)\nAuditory Elements: Note what is heard, such as dialogue, voice-over, music, or sound effects. (max 2 sentences)\n' ], axis=1, inplace=True)

# %%
# Function to calculate the majority vote for each question within each video
def calculate_majority_vote(group):
    results = {}
    for col in group.columns:
        if col not in ['creative_data_id']:
            counts = group[col].value_counts()
            if len(counts) > 1 and counts.iloc[0] == counts.iloc[1]:
                results[col] = group[col].mode()[0]
            else:
                results[col] = counts.idxmax()
    return pd.Series(results)

# %%
#grouping by 'creative_data_id' and calculating majority vote
majority_votes_df = ground_truth_df.groupby('creative_data_id').apply(calculate_majority_vote)
majority_votes_df = majority_votes_df.reset_index()

# Save the processed data to a CSV file
majority_votes_df.to_csv('majority_votes.csv', index=False)
print("Processed majority votes saved to 'majority_votes.csv'.")
# Out:
# Processed majority votes saved to 'majority_votes.csv'.

# %%
results_df.sort_values('creative_data_id', inplace=True)
majority_votes_df.sort_values('creative_data_id', inplace=True)

# %%
#Need to rename the column names of ground-truth to compare with results_df
original_columns = [
    'creative_data_id',
    'Is there a call to go online (e.g., shop online, visit the Web)? ',
    'Is there online contact information provided (e.g., URL, website)? ',
    'Is there a visual or verbal call to purchase (e.g., buy now, order now)?',
    'Does the ad portray a sense of urgency to act (e.g., buy before sales ends, order before ends)? ',
    'Is there an incentive to buy (e.g., a discount, a coupon, a sale or "limited time offer")? ',
    'Is there offline contact information provided (e.g., phone, mail, store location)?',
    'Is there mention of something free? ',
    'Does the ad mention at least one specific product or service (e.g., model, type, item)? ',
    'Is there any verbal or visual mention of the price?',
    'Does the ad show the brand (logo, brand name) or trademark (something that most people know is the brand) multiple times?\n\nFor example, Nike ads often have the "swoosh" logo prominently displayed on shoes and apparel worn by celebrity athletes. The "Just Do It" slogan is another Nike trademark frequently included.',
    'Does the ad show the brand or trademark exactly once at the end of the ad?',
    'Is the ad intended to affect the viewer emotionally, either with positive emotion (fun, joy), negative emotion (sad, anxious) or another type of emotion? (Note: You may not personally agree, but assess if that was the intention.)',
    'Does the ad give you a positive feeling about the brand? ',
    'Does the ad have a story arc, with a beginning and an end? ',
    'Does the ad have a reversal of fortune, where something changes for the better, or changes for the worse?',
    'Does the ad have relatable characters? ', 'Is the ad creative/clever?',
    'Is the ad intended to be funny? (Note: You may not personally agree, but assess if that was the intention.) ',
    'Does this ad provide sensory stimulation (e.g., cool visuals, arousing music, mouth-watering)? ',
    'Is the ad visually pleasing?',
    'Does the ad have cute elements like animals, babies, animated, characters, etc?'
]

new_columns = {original_columns[i]: f'question_{i}' for i in range(1, len(original_columns))}
majority_votes_df.rename(columns=new_columns, inplace=True)

print("Columns have been renamed.")
# Out:
# Columns have been renamed.

# %%
results_df['creative_data_id'] = majority_votes_df['creative_data_id']

# %%
for col in majority_votes_df.columns:
    if 'question' in col:
        majority_votes_df[col] = majority_votes_df[col].str.lower()

# %% [markdown]
# # Metrics calculation

# %%
for i in range(1, 22):
    question_col = f'question_{i}'
    # Converting yes/no to 1/0
    y_true = (majority_votes_df[question_col] == 'yes').astype(int)
    y_pred = (results_df[question_col] == 'yes').astype(int)

    accuracy = accuracy_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)

    print(f"Metrics for {question_col}:")
    print(f"  Agreement Percentage: {accuracy * 100:.2f}%")
    print(f"  F1 Score: {f1:.2f}")
    print(f"  Precision: {precision:.2f}")
    print(f"  Recall: {recall:.2f}")
    print()
# Out:
# Metrics for question_1:
#   Agreement Percentage: 36.00%
#   F1 Score: 0.44
#   Precision: 0.29
#   Recall: 0.97
#
# Metrics for question_2:
#   Agreement Percentage: 45.33%
#   F1 Score: 0.61
#   Precision: 0.45
#   Recall: 0.98
#
# Metrics for question_3:
#   Agreement Percentage: 40.00%
#   F1 Score: 0.54
#   Precision: 0.37
#   Recall: 0.98
#
# Metrics for question_4:
#   Agreement Percentage: 26.00%
#   F1 Score: 0.40
#   Precision: 0.25
#   Recall: 1.00
#
# Metrics for question_5:
#   Agreement Percentage: 42.67%
#   F1 Score: 0.59
#   Precision: 0.42
#   Recall: 1.00
#
# Metrics for question_6:
#   Agreement Percentage: 20.00%
#   F1 Score: 0.29
#   Precision: 0.17
#   Recall: 1.00
#
# Metrics for question_7:
#   Agreement Percentage: 20.00%
#   F1 Score: 0.15
#   Precision: 0.08
#   Recall: 1.00
#
# Metrics for question_8:
#   Agreement Percentage: 83.33%
#   F1 Score: 0.91
#   Precision: 0.85
#   Recall: 0.98
#
# Metrics for question_9:
#   Agreement Percentage: 10.67%
#   F1 Score: 0.00
#   Precision: 0.00
#   Recall: 0.00
#
# Metrics for question_10:
#   Agreement Percentage: 83.33%
#   F1 Score: 0.91
#   Precision: 0.84
#   Recall: 0.98
#
# Metrics for question_11:
#   Agreement Percentage: 83.33%
#   F1 Score: 0.91
#   Precision: 0.85
#   Recall: 0.98
#
# Metrics for question_12:
#   Agreement Percentage: 78.00%
#   F1 Score: 0.88
#   Precision: 0.79
#   Recall: 0.98
#
# Metrics for question_13:
#   Agreement Percentage: 81.33%
#   F1 Score: 0.90
#   Precision: 0.82
#   Recall: 0.98
#
# Metrics for question_14:
#   Agreement Percentage: 23.33%
#   F1 Score: 0.38
#   Precision: 0.23
#   Recall: 1.00
#
# Metrics for question_15:
#   Agreement Percentage: 16.67%
#   F1 Score: 0.22
#   Precision: 0.13
#   Recall: 0.95
#
# Metrics for question_16:
#   Agreement Percentage: 45.33%
#   F1 Score: 0.62
#   Precision: 0.45
#   Recall: 1.00
#
# Metrics for question_17:
#   Agreement Percentage: 62.67%
#   F1 Score: 0.77
#   Precision: 0.63
#   Recall: 0.99
#
# Metrics for question_18:
#   Agreement Percentage: 26.67%
#   F1 Score: 0.34
#   Precision: 0.20
#   Recall: 0.97
#
# Metrics for question_19:
#   Agreement Percentage: 55.33%
#   F1 Score: 0.71
#   Precision: 0.55
#   Recall: 1.00
#
# Metrics for question_20:
#   Agreement Percentage: 68.67%
#   F1 Score: 0.81
#   Precision: 0.69
#   Recall: 1.00
#
# Metrics for question_21:
#   Agreement Percentage: 27.33%
#   F1 Score: 0.37
#   Precision: 0.23
#   Recall: 0.94
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 due to no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
